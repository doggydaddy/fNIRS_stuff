# %%
# testing what is the block duration of a stroop task
# loading other support functions
source('fnirs_rfunctions.R')
# testing EDA preprocessing
# load random datasets for testing
dat <- importData('Fatigue_files_for_Yanlu_180323/BJ-4714/BJ-4714_stroop_post.txt') #stroop
blockIdx <- getBlockStarts_stroop( dat$glm1, dat$glm2)
sumglm <- fixglm_stroop_vft(dat$glm1+dat$glm2)
plot(sumglm, type='l')
abline(v=blockIdx[2], col=2)
offset <- 240
# 30 seconds * 8 Hz = 240 time units
abline(v=blockIdx[2]+offset, col=4)
# Out:
# plot without title
